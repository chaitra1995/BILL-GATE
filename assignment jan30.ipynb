# %%
1.write a program to accept  percentage from the user and display the grade  according  to the following criteria .
marks	Grade
>90	A
>80 and <=90	B
>=60  and <=80	C
below	D


Ans: marks=int(input("enter the marks"))
       if (marks>90):
            print("student scored with A grade")
      elif(marks>80 and marks<=90):
            print("student scored with B grade")
     elif(marks>=60 and marks<=80):
             print("student scored with C grade")
      elif(marks<=60):
             print("student scored with D grade")

# %%
2. write  a  program to accept the  cost price  of a bike  and  display  the  road tax to be paid  according  to the following criteria:
Tax	Cost price( in rs)
15%	>100000
10%	>50000  and <=100000
5%	<=50000
cost_price=float(input("enter the cost price of bike"))
if cost_price>100000:
    t=0.15*cost_price
    print(t,"the road tax to be paid")
elif cost_price>50000 and cost_price<=100000:
    t=0.10*cost_price
    print(t,"the road tax to be paid")
elif cost_price<=50000:
    t=0.05*cost_price
    print(t,"the road tax to be paid")

# %%
3.Accept any city from the user and display monuments of that city
City	Monument
Delhi	Red fort
Agra	Taj Mahal
jaipur	Jal Mahal

city=input("enter the city for monuments")
if city.lower()== "Delhi":
    print("Red fort")
elif city.lower()=="Agra":
    print("Taj mahal")
elif city.lower()=="jaipur":
     print("jal mahal")
else:
     print("invalid input")

# %%
4. check  how many times  a given numbers can be divided by 3 before it is less than  or equal to 10.
count=0
number=180
while number>10:
    number=number/3
    count=count+1
print("total iteration required",count)

# %%
5. why and when to use while loop in python give a detailed  description with example.
Python while loop is used to run  a block  code until  a  certain condition is met.
The syntax of while loop is :
While  condition :
# body of while loop
Here,
1.A while loop evaluates the condition
2.if condition evaluates to true ,the code inside the while loop is executed.
3.Condition is evaluated.
4.This process is continues until the condition is false.
5.when condition evaluates loop stops.
Example:
Program to display numbers from  1 to 5
i=1
n=5
while  i<=n:
   print(i)
  i=i+1

# %%
6. Use nested while loop to print 3 different patterns.
a. 1
    22
    333
    4444
    55555
n=6
for i in range(n):
    for j in range(i):
        print(i, end="")
    print()

b.  *
      **
       ***
       ****
       *****

n=5
for i in range(0,rows):
    for j in range(0,i+1):
        print ("*", end="")
    print("\r")

c.
   1
   33
   555
   7777
   99999
 
rows=5
i=1
while i<=5:
    j=1
    while j<=i:
        print((i*2-1),end="")
        j=j+1
    i=i+1
    print('')

# %%
7.Reverse the while loop to display number from 10 to  1

i=1
n=10
while i>=10:
    print(i)
    i=i-1
